# %% [markdown]
# #### Step 1 - Imports

# %%
import requests

# %% [markdown]
# #### Step 2 - CURL

# %%
headers = {
    'authority': 'www.autolist.com',
    'accept': '*/*',
    'x-requested-with': 'XMLHttpRequest',
    'x-autolist-session-guid': 'd5e362b6-dadc-452e-8c91-39c6dd3f381d',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/97.0.4692.71 Safari/537.36',
    'sec-gpc': '1',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-mode': 'cors',
    'sec-fetch-dest': 'empty',
    'referer': 'https://www.autolist.com/listings',
    'accept-language': 'ru-RU,ru;q=0.9',
    'cookie': 'ec=eyJlZGdlVXNlckFnZW50IjoiTW96aWxsYS81LjAgKFdpbmRvd3MgTlQgMTAuMDsgV2luNjQ7IHg2NCkgQXBwbGVXZWJLaXQvNTM3LjM2IChLSFRNTCwgbGlrZSBHZWNrbykgQ2hyb21lLzk3LjAuNDY5Mi43MSBTYWZhcmkvNTM3LjM2In0=; client_guid_timestamp=a9bfb9f7-4811-4f77-b7f0-07feee46e5e4.1642750272872; scavenger-a493=...; _fbp=fb.1.1642750273301.950266984',
}

params = (
    ('make', 'Tesla'),
    ('radius', '50'),
    ('page', '1'),
)

response = requests.get('https://www.autolist.com/api/cwv/seo/listings', headers=headers, params=params)

# %% [markdown]
# #### Step 3 - Check Status Code

# %%
response
# Out:
# <Response [200]>

# %% [markdown]
# #### Step 4 - Create Json Object

# %%
results_json = response.json()

# %%
results_json
# Out:
# {'total_results_count': 6879,
#  'make_model_name': 'Tesla',
#  'trims': [],
#  'ad_info': {'ad_unit': '/19485787/AutoList.com/Search_Results_Page/Tesla',
#   'make': 'Tesla',
#   'model': None,
#   'page_type': 'srp',
#   'cpo': False,
#   'body_style': None,
#   'year': 2023,
#   'age_type': 'new',
#   'app': 'web',
#   'seller_id': None,
#   'content_url': 'https://www.autolist.com/listings#make=Tesla&page=1&radius=50'},
#  'search_results': [{'available_nationwide': False,
#    'created_at': 1640188755,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EA3JF003242',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EA3JF003242',
#    'clickoff_url': 'www.coronamotorsdirect.com?utm_source=autolist&utm_medium=referral&utm_campaign=vdp_deep_link',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 233934017,
# ...

# %%
type(results_json)
# Out:
# dict

# %% [markdown]
# #### Step 5 - Output Keys

# %%
results_json.keys()
# Out:
# dict_keys(['total_results_count', 'make_model_name', 'trims', 'ad_info', 'search_results', 'html'])

# %% [markdown]
# #### Step 6 - Find your Data

# %% [markdown]
# #### Step 7 - Put everything together - Loop through results and append data inside a list

# %% [markdown]
# #### Step 8 - Pandas Dataframe - Single Page

# %% [markdown]
# #### Step 9 - Scraping Multiple Pages (here: 5pages to get 100 results)

# %% [markdown]
# #### Step 10 - Store Results in Excel
