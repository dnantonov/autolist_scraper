# %% [markdown]
# #### Step 1 - Imports

# %%
import requests
import pandas as pd

# %% [markdown]
# #### Step 2 - CURL

# %%
headers = {
    'authority': 'www.autolist.com',
    'sec-ch-ua': '^\\^Chromium^\\^;v=^\\^94^\\^, ^\\^Google',
    'accept': '*/*',
    'x-requested-with': 'XMLHttpRequest',
    'sec-ch-ua-mobile': '?0',
    'x-autolist-session-guid': 'c9fb9ffb-2c06-4468-a3d0-c26290c6994f',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4590.0 Safari/537.36',
    'sec-ch-ua-platform': '^\\^Windows^\\^',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-mode': 'cors',
    'sec-fetch-dest': 'empty',
    'referer': 'https://www.autolist.com/listings',
    'accept-language': 'en-US,en;q=0.9',
    'cookie': 'ec=eyJlZGdlVXNlckFnZW50IjoiTW96aWxsYS81LjAgKFdpbmRvd3MgTlQgMTAuMDsgV2luNjQ7IHg2NCkgQXBwbGVXZWJLaXQvNTM3LjM2IChLSFRNTCwgbGlrZSBHZWNrbykgQ2hyb21lLzk0LjAuNDU5MC4wIFNhZmFyaS81MzcuMzYifQ==; client_guid_timestamp=1602952f-d1bf-4936-82e3-cbdedfa11d2d.1627825394925; scavenger-a493=...; _sp_ses.8ca5=*; _gid=GA1.2.96049973.1627825395; _fbp=fb.1.1627825395573.409117512; __gads=ID=c459f8bf6d0987dd:T=1627825394:S=ALNI_MaW1epD3HNJsvJQTCnPWSJCcOdE_w; AMP_TOKEN=^%^24NOT_FOUND; sp-nuid=e4461948-a1a2-45a1-88f8-45c2889d9576; _gcl_au=1.1.519751617.1627825557; _ga_152345333=GS1.1.1627825395.1.1.1627828426.0; _ga=GA1.2.2118379867.1627825395; cto_bundle=WV1etl8zMUc1cGt6WnZNSEZMYWhwNnJjUXpTYzQxVzZ6QzM5VE1tWXZFcjQ3ZWhrNTlETG1CemlUdmNFYUtIbXdCQTNFelJmY3h6QXA0SlVIZml0WVg2OWQxZlBPMmRqbExXNU9XZTM0V0VaR09tbHBvJTJGdERCb21zZUVKJTJCTG1vVzlDV0w2VjA0bDklMkJnRjdrMmZPUExmJTJGY0l6USUzRCUzRA; _gat=1; _sp_id.8ca5=d3d3f60d-371c-4289-92fe-1c6f66b4979f.1627825395.1.1627828912.1627825395.8bc1e545-8ca1-448e-b1ba-ec8d2c359ada',
    'if-none-match': 'W/^\\^c6f72fa4ef059e03ea0309ebd57c197d^\\^',
}

params = (
    ('make', 'Tesla'),
    ('zip', '198099'),
    ('location', 'Sankt-Peterburg'),
    ('latitude', '59.897206'),
    ('longitude', '30.2604628'),
    ('radius', '50'),
    ('page', '1'),
)

response = requests.get('https://www.autolist.com/api/cwv/seo/listings', headers=headers, params=params)

# %% [markdown]
# #### Step 3 - Check Status Code

# %%
response
# Out:
# <Response [200]>

# %% [markdown]
# #### Step 4 - Create Json Object

# %%
results_json = response.json()

# %%
results_json
# Out:
# {'total_results_count': 341,
#  'make_model_name': 'Tesla',
#  'trims': [],
#  'ad_info': {'ad_unit': '/19485787/AutoList.com/Search_Results_Page/Tesla',
#   'make': 'Tesla',
#   'model': None,
#   'page_type': 'srp',
#   'cpo': False,
#   'body_style': None,
#   'year': 2023,
#   'age_type': 'new',
#   'app': 'web',
#   'seller_id': None,
#   'content_url': 'https://www.autolist.com/listings#latitude=59.897206&location=Sankt-Peterburg&longitude=30.2604628&make=Tesla&page=1&radius=50&zip=198099'},
#  'search_results': [{'available_nationwide': False,
#    'created_at': 1642657502,
#    'recent_price_drop': None,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EB2LF647875',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EB2LF647875',
#    'clickoff_url': 'https://www.carmax.com/car/21676488?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 235652559,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21676488/1.jpg?width=1024&watermark=LYCG_1a',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--4RWLmo9_--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21676488/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#    'lat': 32.843399,
#    'lon': -96.898399,
#    'year': 2020,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$52,998',
#    'price_unformatted': 52998,
#    'mileage': '25,813 Miles',
#    'mileage_unformatted': 25813,
#    'city': 'Irving',
#    'state': 'TX',
#    'distance_from_origin': 5361,
#    'dealer_name': 'CarMax Texas Stadium (Irving) - Now Offering Curbside Pickup And Home Delivery',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJ3E1EB2LF647875',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '5YJ3E1EB2LF647875',
#     'remote_dealer_id': '7115',
#     'dealer_name': 'CarMax Texas Stadium (Irving)',
#     'remote_sku': '21676488',
#     'experience': 'national_backfill',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_tx_stadium',
#     'dealer_uuid': '9cd88c7b-05af-4d4c-813e-05887e3bc6e5',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': 'Long Range',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': True,
#    'badges': {'position0': None, 'position1': 'fresh'},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1642311878,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJYGDEE9LF037144',
#    'vdp_url': '/tesla-model+y#vin=5YJYGDEE9LF037144',
#    'clickoff_url': 'https://www.carmax.com/car/21634963?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 235444093,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21634963/1.jpg?width=1024&watermark=LYCG_1a',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--NyWKBusk--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21634963/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#    'lat': 35.159805,
#    'lon': -80.732605,
#    'year': 2020,
#    'make': 'Tesla',
#    'model': 'Model Y',
#    'model_id': 2357,
#    'display_color': '',
#    'price': '$66,998',
#    'price_unformatted': 66998,
#    'mileage': '25,125 Miles',
#    'mileage_unformatted': 25125,
#    'city': 'Charlotte',
#    'state': 'NC',
#    'distance_from_origin': 4797,
#    'dealer_name': 'CarMax Independence Boulevard - Now Offering Curbside Pickup And Home Delivery',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJYGDEE9LF037144',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '5YJYGDEE9LF037144',
#     'remote_dealer_id': '7106',
#     'dealer_name': 'CarMax Charlotte',
#     'remote_sku': '21634963',
#     'experience': 'national_backfill',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_charlotte',
#     'dealer_uuid': '96441764-9288-4d1c-9f86-10e58dcb580a',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': 'Long Range',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1642052749,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EC0MF936330',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EC0MF936330',
#    'clickoff_url': 'https://www.carmax.com/car/21846359?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 235203984,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21846359/1.jpg?width=1024&watermark=LYCG_1a',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--j611PBXJ--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21846359/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#    'lat': 33.27750723911677,
#    'lon': -111.735905469218,
#    'year': 2021,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$64,998',
#    'price_unformatted': 64998,
#    'mileage': '11,430 Miles',
#    'mileage_unformatted': 11430,
#    'city': 'Gilbert',
#    'state': 'AZ',
#    'distance_from_origin': 5645,
#    'dealer_name': 'CarMax Phoenix-Gilbert - Now Offering Curbside Pickup',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJ3E1EC0MF936330',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '5YJ3E1EC0MF936330',
#     'remote_dealer_id': '7662',
#     'dealer_name': 'CarMax Phoenix-Gilbert',
#     'remote_sku': '21846359',
#     'experience': 'national_backfill',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_phoenix_gilbert',
#     'dealer_uuid': 'cc7db436-aae0-48a3-a245-ef29e8edc722',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': 'Performance',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1637726303,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EA8MF920097',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EA8MF920097',
#    'clickoff_url': 'https://www.carmax.com/car/21535430?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 232103004,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21535430/1.jpg?width=1024&watermark=LYCG_1a',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--kVn6RNFy--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21535430/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#    'lat': 43.57342334079856,
#    'lon': -116.4013098816062,
#    'year': 2021,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$51,998',
#    'price_unformatted': 51998,
#    'mileage': '9,330 Miles',
#    'mileage_unformatted': 9330,
#    'city': 'Meridian',
#    'state': 'ID',
#    'distance_from_origin': 5042,
#    'dealer_name': 'CarMax Boise (Meridian) - Now Offering Curbside Pickup',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJ3E1EA8MF920097',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '5YJ3E1EA8MF920097',
#     'remote_dealer_id': '6039',
#     'dealer_name': 'CarMax Boise (Meridian)',
#     'remote_sku': '21535430',
#     'experience': 'national_backfill',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_boise_meridian',
#     'dealer_uuid': 'ceec9e6c-39bd-4db4-a1cd-b13651fe2daa',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': 'Standard Range Plus',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1642657504,
#    'recent_price_drop': None,
#    'is_hot': False,
#    'href_target': '/listings/5YJYGDEE2MF073677',
#    'vdp_url': '/tesla-model+y#vin=5YJYGDEE2MF073677',
#    'clickoff_url': 'https://www.carmax.com/car/21731461?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 235652967,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21731461/1.jpg?width=1024&watermark=LYCG_1a',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--Hxf9OFOT--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21731461/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#    'lat': 35.892673,
#    'lon': -78.55385,
#    'year': 2021,
#    'make': 'Tesla',
#    'model': 'Model Y',
#    'model_id': 2357,
#    'display_color': '',
#    'price': '$69,998',
#    'price_unformatted': 69998,
#    'mileage': '5,173 Miles',
#    'mileage_unformatted': 5173,
#    'city': 'Raleigh',
#    'state': 'NC',
#    'distance_from_origin': 4691,
#    'dealer_name': 'CarMax Capital Boulevard - Now Offering Curbside Pickup And Home Delivery',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJYGDEE2MF073677',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '5YJYGDEE2MF073677',
#     'remote_dealer_id': '7282',
#     'dealer_name': 'CarMax Capital Boulevard',
#     'remote_sku': '21731461',
#     'experience': 'national_backfill',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_capital_boulevard',
#     'dealer_uuid': '37dab682-0d2a-4174-b8d0-187d7ede25c7',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': 'Long Range',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': True,
#    'badges': {'position0': None, 'position1': 'fresh'},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1642139500,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EA8MF020543',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EA8MF020543',
#    'clickoff_url': 'https://www.carmax.com/car/21714781?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 235285547,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21714781/1.jpg?width=1024&watermark=LYCG_1a',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--PoXBn-ps--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21714781/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#    'lat': 26.097263,
#    'lon': -80.245949,
#    'year': 2021,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$51,998',
#    'price_unformatted': 51998,
#    'mileage': '8,051 Miles',
#    'mileage_unformatted': 8051,
#    'city': 'Davie',
#    'state': 'FL',
#    'distance_from_origin': 5329,
#    'dealer_name': 'CarMax Ft. Lauderdale - Now Offering Curbside Pickup And Home Delivery',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJ3E1EA8MF020543',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '5YJ3E1EA8MF020543',
#     'remote_dealer_id': '7108',
#     'dealer_name': 'CarMax Ft. Lauderdale',
#     'remote_sku': '21714781',
#     'experience': 'national_backfill',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_ft_lauderdale',
#     'dealer_uuid': 'e021e97a-0130-48f0-a061-638533e61fbd',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': 'Standard Range Plus',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1641793113,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EA2MF092029',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EA2MF092029',
#    'clickoff_url': 'https://www.carmax.com/car/21814324?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 235018238,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21814324/1.jpg?width=1024&watermark=LYCG_1a',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--L8Sw8qNm--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21814324/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#    'lat': 35.707237,
#    'lon': -81.305038,
#    'year': 2021,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$49,998',
#    'price_unformatted': 49998,
#    'mileage': '1,900 Miles',
#    'mileage_unformatted': 1900,
#    'city': 'Hickory',
#    'state': 'NC',
#    'distance_from_origin': 4780,
#    'dealer_name': 'CarMax Hickory - Now Offering Curbside Pickup And Home Delivery',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJ3E1EA2MF092029',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '5YJ3E1EA2MF092029',
#     'remote_dealer_id': '7231',
#     'dealer_name': 'CarMax Hickory',
#     'remote_sku': '21814324',
#     'experience': 'national_backfill',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_hickory',
#     'dealer_uuid': '0062325e-2e3a-494f-8296-9d4acc6d6e61',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': 'Standard Range Plus',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1642218150,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EA0MF058932',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EA0MF058932',
#    'clickoff_url': 'https://www.carmax.com/car/21203815?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 235357867,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21203815/1.jpg?width=1024&watermark=LYCG_1a',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--0f-rVBTn--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21203815/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#    'lat': 34.08762181731687,
#    'lon': -83.94131109254148,
#    'year': 2021,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$53,998',
#    'price_unformatted': 53998,
#    'mileage': '2,097 Miles',
#    'mileage_unformatted': 2097,
#    'city': 'Buford',
#    'state': 'GA',
#    'distance_from_origin': 4951,
#    'dealer_name': 'CarMax Buford - Now Offering Curbside Pickup And Home Delivery',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJ3E1EA0MF058932',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '5YJ3E1EA0MF058932',
#     'remote_dealer_id': '6031',
#     'dealer_name': 'CarMax Buford',
#     'remote_sku': '21203815',
#     'experience': 'national_backfill',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_buford',
#     'dealer_uuid': 'c889115b-42e1-4bb7-a6b2-a24c23e47c5a',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': 'Standard Range Plus',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1642574077,
#    'recent_price_drop': True,
#    'is_hot': False,
#    'href_target': '/listings/5YJYGDED1MF103193',
#    'vdp_url': '/tesla-model+y#vin=5YJYGDED1MF103193',
#    'clickoff_url': 'https://www.carmax.com/car/21841351?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 235574176,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21841351/1.jpg?width=1024&watermark=LYCG_1a',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--jdspCU1s--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21841351/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#    'lat': 39.723848,
#    'lon': -105.185903,
#    'year': 2021,
#    'make': 'Tesla',
#    'model': 'Model Y',
#    'model_id': 2357,
#    'display_color': '',
#    'price': '$62,998',
#    'price_unformatted': 62998,
#    'mileage': '11,355 Miles',
#    'mileage_unformatted': 11355,
#    'city': 'Golden',
#    'state': 'CO',
#    'distance_from_origin': 5103,
#    'dealer_name': 'CarMax Golden - Now Offering Curbside Pickup And Home Delivery',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJYGDED1MF103193',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '5YJYGDED1MF103193',
#     'remote_dealer_id': '6047',
#     'dealer_name': 'CarMax Golden',
#     'remote_sku': '21841351',
#     'experience': 'national_backfill',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_golden',
#     'dealer_uuid': 'a1ce32c8-c56c-47a6-88bc-317076285732',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': 'Standard Range',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': True,
#    'badges': {'position0': None, 'position1': 'price_drop'},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1642225503,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EB5JF113346',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EB5JF113346',
#    'clickoff_url': 'https://www.carmax.com/car/21763670?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 235368927,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21763670/1.jpg?width=1024&watermark=LYCG_1a',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--8j496LmM--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21763670/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#    'lat': 39.009819,
#    'lon': -77.436104,
#    'year': 2018,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$55,998',
#    'price_unformatted': 55998,
#    'mileage': '19,346 Miles',
#    'mileage_unformatted': 19346,
#    'city': 'Sterling',
#    'state': 'VA',
#    'distance_from_origin': 4475,
#    'dealer_name': 'CarMax Dulles - Now Offering Curbside Pickup And Home Delivery',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJ3E1EB5JF113346',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '5YJ3E1EB5JF113346',
#     'remote_dealer_id': '7132',
#     'dealer_name': 'CarMax Dulles',
#     'remote_sku': '21763670',
#     'experience': 'national_backfill',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_dulles',
#     'dealer_uuid': '23575ced-c04b-435e-bf7a-cc2eb9716958',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': 'Performance',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1642657475,
#    'recent_price_drop': None,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EB0LF801788',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EB0LF801788',
#    'clickoff_url': 'https://www.carmax.com/car/21327936?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 235649953,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21327936/1.jpg?width=1024&watermark=LYCG_1a',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--5H8UYZym--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21327936/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#    'lat': 39.536456,
#    'lon': -104.777566,
#    'year': 2020,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$54,998',
#    'price_unformatted': 54998,
#    'mileage': '21,657 Miles',
#    'mileage_unformatted': 21657,
#    'city': 'Parker',
#    'state': 'CO',
#    'distance_from_origin': 5107,
#    'dealer_name': 'CarMax Parker - Now Offering Curbside Pickup And Home Delivery',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJ3E1EB0LF801788',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '5YJ3E1EB0LF801788',
#     'remote_dealer_id': '6010',
#     'dealer_name': 'CarMax Parker',
#     'remote_sku': '21327936',
#     'experience': 'national_backfill',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_parker',
#     'dealer_uuid': '0bf2bb92-5a5c-4ea9-9b3c-9c9c2f50d9d4',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': 'Long Range',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': True,
#    'badges': {'position0': None, 'position1': 'fresh'},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1641620291,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJSA1E4XJF269701',
#    'vdp_url': '/tesla-model+s#vin=5YJSA1E4XJF269701',
#    'clickoff_url': 'https://www.carmax.com/car/21477558?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 234906584,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21477558/1.jpg?width=1024&watermark=LYCG_1a',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--Jv3utlgu--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21477558/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#    'lat': 34.08762181731687,
#    'lon': -83.94131109254148,
#    'year': 2018,
#    'make': 'Tesla',
#    'model': 'Model S',
#    'model_id': 2006,
#    'display_color': '',
#    'price': '$83,998',
#    'price_unformatted': 83998,
#    'mileage': '31,061 Miles',
#    'mileage_unformatted': 31061,
#    'city': 'Buford',
#    'state': 'GA',
#    'distance_from_origin': 4951,
#    'dealer_name': 'CarMax Buford - Now Offering Curbside Pickup And Home Delivery',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJSA1E4XJF269701',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '5YJSA1E4XJF269701',
#     'remote_dealer_id': '6031',
#     'dealer_name': 'CarMax Buford',
#     'remote_sku': '21477558',
#     'experience': 'national_backfill',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_buford',
#     'dealer_uuid': 'c889115b-42e1-4bb7-a6b2-a24c23e47c5a',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': 'P100D',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1635917648,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EC6LF669239',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EC6LF669239',
#    'clickoff_url': 'https://www.carmax.com/car/21428251?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 230729809,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21428251/1.jpg?width=1024&watermark=LYCG_1a',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--e0R3Ei1w--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21428251/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#    'lat': 41.63382176507668,
#    'lon': -93.73456214956924,
#    'year': 2020,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$63,998',
#    'price_unformatted': 63998,
#    'mileage': '12,236 Miles',
#    'mileage_unformatted': 12236,
#    'city': 'Urbandale',
#    'state': 'IA',
#    'distance_from_origin': 4738,
#    'dealer_name': 'CarMax Des Moines - Now Offering Curbside Pickup',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJ3E1EC6LF669239',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '5YJ3E1EC6LF669239',
#     'remote_dealer_id': '6004',
#     'dealer_name': 'CarMax Des Moines',
#     'remote_sku': '21428251',
#     'experience': 'national_backfill',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_des_moines',
#     'dealer_uuid': '9544c995-51e7-4b0a-9680-255fd5e26caf',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': 'Performance',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1637127831,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EB9JF119392',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EB9JF119392',
#    'clickoff_url': 'https://www.carmax.com/car/21529925?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 231641143,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21529925/1.jpg?width=1024&watermark=LYCG_1a',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--ecJ2zE5j--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21529925/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#    'lat': 34.22445047136432,
#    'lon': -118.6334774051356,
#    'year': 2018,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$50,998',
#    'price_unformatted': 50998,
#    'mileage': '20,895 Miles',
#    'mileage_unformatted': 20895,
#    'city': 'Canoga Park',
#    'state': 'CA',
#    'distance_from_origin': 5696,
#    'dealer_name': 'CarMax Canoga Park - Now Offering Curbside Pickup And Home Delivery',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJ3E1EB9JF119392',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '5YJ3E1EB9JF119392',
#     'remote_dealer_id': '7124',
#     'dealer_name': 'CarMax Canoga Park',
#     'remote_sku': '21529925',
#     'experience': 'national_backfill',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_canoga_park',
#     'dealer_uuid': '60fcb806-1728-4076-8ad1-4db049729175',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': 'Long Range',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1641620293,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EA7MF064534',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EA7MF064534',
#    'clickoff_url': 'https://www.carmax.com/car/21671558?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 234906767,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21671558/1.jpg?width=1024&watermark=LYCG_1a',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--IViPIN_J--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21671558/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#    'lat': 47.81055093002225,
#    'lon': -122.2807501062141,
#    'year': 2021,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$49,998',
#    'price_unformatted': 49998,
#    'mileage': '2,400 Miles',
#    'mileage_unformatted': 2400,
#    'city': 'Lynnwood',
#    'state': 'WA',
#    'distance_from_origin': 4836,
#    'dealer_name': 'CarMax Lynnwood - Now Offering Curbside Pickup',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJ3E1EA7MF064534',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '5YJ3E1EA7MF064534',
#     'remote_dealer_id': '7250',
#     'dealer_name': 'CarMax Lynnwood',
#     'remote_sku': '21671558',
#     'experience': 'national_backfill',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_lynnwood',
#     'dealer_uuid': '04cb1617-8ff4-4348-80b1-7c6e0dd411b8',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': 'Standard Range Plus',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1641620293,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EB7LF638721',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EB7LF638721',
#    'clickoff_url': 'https://www.carmax.com/car/21685810?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 234906777,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21685810/1.jpg?width=1024&watermark=LYCG_1a',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--6vAhPm8a--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21685810/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#    'lat': 37.691496,
#    'lon': -121.847734,
#    'year': 2020,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$56,998',
#    'price_unformatted': 56998,
#    'mileage': '6,978 Miles',
#    'mileage_unformatted': 6978,
#    'city': 'Pleasanton',
#    'state': 'CA',
#    'distance_from_origin': 5509,
#    'dealer_name': 'CarMax Pleasanton - Now Open',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJ3E1EB7LF638721',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '5YJ3E1EB7LF638721',
#     'remote_dealer_id': '6068',
#     'dealer_name': 'CarMax Pleasanton',
#     'remote_sku': '21685810',
#     'experience': 'national_backfill',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_pleasanton',
#     'dealer_uuid': 'aa30dd9c-1b75-4a66-a7d3-078716560d2a',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': 'Long Range',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1641965673,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EA7LF793275',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EA7LF793275',
#    'clickoff_url': 'https://www.carmax.com/car/21580598?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 235117629,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21580598/1.jpg?width=1024&watermark=LYCG_1a',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--ZLrRzPEu--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21580598/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#    'lat': 38.68322332188854,
#    'lon': -77.3151275475306,
#    'year': 2020,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$49,998',
#    'price_unformatted': 49998,
#    'mileage': '9,006 Miles',
#    'mileage_unformatted': 9006,
#    'city': 'Woodbridge',
#    'state': 'VA',
#    'distance_from_origin': 4491,
#    'dealer_name': 'CarMax Potomac Mills - Now Offering Curbside Pickup And Home Delivery',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJ3E1EA7LF793275',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '5YJ3E1EA7LF793275',
#     'remote_dealer_id': '7183',
#     'dealer_name': 'CarMax Potomac Mills',
#     'remote_sku': '21580598',
#     'experience': 'national_backfill',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_potomac_mills',
#     'dealer_uuid': '6ebede17-d435-4c4f-b7f8-f6eedfb40ff6',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': 'Standard Range Plus',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1642052737,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EA2JF109150',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EA2JF109150',
#    'clickoff_url': 'https://www.carmax.com/car/21799330?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 235199330,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21799330/1.jpg?width=1024&watermark=LYCG_1a',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--9u137Oim--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21799330/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#    'lat': 41.54908,
#    'lon': -87.783585,
#    'year': 2018,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$47,998',
#    'price_unformatted': 47998,
#    'mileage': '18,533 Miles',
#    'mileage_unformatted': 18533,
#    'city': 'Tinley Park',
#    'state': 'IL',
#    'distance_from_origin': 4600,
#    'dealer_name': 'CarMax Tinley Park - Now Offering Curbside Pickup',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJ3E1EA2JF109150',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '5YJ3E1EA2JF109150',
#     'remote_dealer_id': '7123',
#     'dealer_name': 'CarMax Tinley Park',
#     'remote_sku': '21799330',
#     'experience': 'national_backfill',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_tinley_park',
#     'dealer_uuid': '97ab92b0-3a56-48f4-8961-b8a65074eed7',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': 'Long Range',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1640065422,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EC7LF736382',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EC7LF736382',
#    'clickoff_url': 'https://www.carmax.com/car/21199485?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 233835751,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21199485/1.jpg?width=1024&watermark=LYCG_1a',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--bruDAj03--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21199485/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#    'lat': 39.39208799035347,
#    'lon': -76.40076215697658,
#    'year': 2020,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$57,998',
#    'price_unformatted': 57998,
#    'mileage': '27,736 Miles',
#    'mileage_unformatted': 27736,
#    'city': 'White Marsh',
#    'state': 'MD',
#    'distance_from_origin': 4424,
#    'dealer_name': 'CarMax White Marsh - Now Offering Curbside Pickup',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJ3E1EC7LF736382',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '5YJ3E1EC7LF736382',
#     'remote_dealer_id': '7121',
#     'dealer_name': 'CarMax White Marsh',
#     'remote_sku': '21199485',
#     'experience': 'national_backfill',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_white_marsh',
#     'dealer_uuid': '55714391-254e-4c7b-b1b8-497bbdb16a9d',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': 'Performance',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1641620291,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EA6MF069580',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EA6MF069580',
#    'clickoff_url': 'https://www.carmax.com/car/21900916?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 234906564,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21900916/1.jpg?width=1024&watermark=LYCG_1a',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--QOLLKqpM--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21900916/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#    'lat': 34.23518276789216,
#    'lon': -119.180077971384,
#    'year': 2021,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$50,998',
#    'price_unformatted': 50998,
#    'mileage': '7,872 Miles',
#    'mileage_unformatted': 7872,
#    'city': 'Oxnard',
#    'state': 'CA',
#    'distance_from_origin': 5703,
#    'dealer_name': 'CarMax Oxnard - Now Offering Curbside Pickup And Home Delivery',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJ3E1EA6MF069580',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '5YJ3E1EA6MF069580',
#     'remote_dealer_id': '6014',
#     'dealer_name': 'CarMax Oxnard',
#     'remote_sku': '21900916',
#     'experience': 'national_backfill',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_oxnard',
#     'dealer_uuid': 'dfee9eab-fb2c-4d95-b57b-61908c33aa04',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': 'Standard Range Plus',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False}],
#  'html': {'search_results': '<a class="AL-vehicle-item -small-md -stacked-sm -stacked-xs -popout-action" href="/tesla-model+3#vin=5YJ3E1EB2LF647875"><div class=\'photo\'>\n<div class=\'AL-vehicle-photo\'>\n<div class=\'viewed-overlay hidden\'></div>\n<div class=\'photo-overlay\'></div>\n<div class=\'overlay-menu\' data-menu>\n<div class=\'-favorite -results-gtsm item\' data-action=\'favorite\'></div>\n</div>\n<div class=\'photo\' style=\'background-image: url(https://images.autolist.com/image/fetch/s--4RWLmo9_--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21676488/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a)\' title=\'used 2020 Tesla Model 3 Long Range White 5YJ3E1EB2LF647875\'></div>\n</div>\n<div class=\'badges-container\'>\n<div class=\'outer-container\'>\n<div class=\'\' data-spot=\'0\'>\n\n</div>\n<div class=\'badge fresh\' data-spot=\'1\'>\nFresh\n</div>\n</div>\n</div>\n</div>\n<div class=\'details\'>\n<h3 class=\'AL-vehicle-primary-details -small-sm -small-xs\'>\n<div class=\'description\'>\n<div class=\'headline\'>2020 Tesla Model 3 Long Range</div>\n<div class=\'subtext\'>\n25,813 Miles\n<span class=\'divider\'>\n|\n</span>\n<span class=\'location\'>Transfer Available</span>\n</div>\n</div>\n<div class=\'pricing\'>\n<div class=\'headline\'>$52,998</div>\n<div class=\'monthly-payment\' data-menu data-monthly-payment>\n<span class=\'info-link\' href=\'javascript:void(0);\'>\nest. $764/mo\n<i></i>\n</span>\n</div>\n</div>\n</h3>\n<div class=\'AL-vehicle-secondary-details -small-sm -small-xs\' data-menu>\n<div class=\'action\'>\n<span class=\'\' data-action=\'track price\'>\nTrack Price\n</span>\n<span class=\'popout-item\' data-action=\'check availability\'>\nCheck Availability\n</span>\n</div>\n</div>\n</div>\n</a>\n<a class="AL-vehicle-item -small-md -stacked-sm -stacked-xs -popout-action" href="/tesla-model+y#vin=5YJYGDEE9LF037144"><div class=\'photo\'>\n<div class=\'AL-vehicle-photo\'>\n<div class=\'viewed-overlay hidden\'></div>\n<div class=\'photo-overlay\'></div>\n<div class=\'overlay-menu\' data-menu>\n<div class=\'-favorite -results-gtsm item\' data-action=\'favorite\'></div>\n</div>\n<div class=\'photo\' style=\'background-image: url(https://images.autolist.com/image/fetch/s--NyWKBusk--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21634963/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a)\' title=\'used 2020 Tesla Model Y Long Range White 5YJYGDEE9LF037144\'></div>\n</div>\n<div class=\'badges-container\'>\n<div class=\'outer-container\'>\n<div class=\'\' data-spot=\'0\'>\n\n</div>\n<div class=\'\' data-spot=\'1\'>\n\n</div>\n</div>\n</div>\n</div>\n<div class=\'details\'>\n<h3 class=\'AL-vehicle-primary-details -small-sm -small-xs\'>\n<div class=\'description\'>\n<div class=\'headline\'>2020 Tesla Model Y Long Range</div>\n<div class=\'subtext\'>\n25,125 Miles\n<span class=\'divider\'>\n|\n</span>\n<span class=\'location\'>Transfer Available</span>\n</div>\n</div>\n<div class=\'pricing\'>\n<div class=\'headline\'>$66,998</div>\n<div class=\'monthly-payment\' data-menu data-monthly-payment>\n<span class=\'info-link\' href=\'javascript:void(0);\'>\nest. $966/mo\n<i></i>\n</span>\n</div>\n</div>\n</h3>\n<div class=\'AL-vehicle-secondary-details -small-sm -small-xs\' data-menu>\n<div class=\'action\'>\n<span class=\'\' data-action=\'track price\'>\nTrack Price\n</span>\n<span class=\'popout-item\' data-action=\'check availability\'>\nCheck Availability\n</span>\n</div>\n</div>\n</div>\n</a>\n<a class="AL-vehicle-item -small-md -stacked-sm -stacked-xs -popout-action" href="/tesla-model+3#vin=5YJ3E1EC0MF936330"><div class=\'photo\'>\n<div class=\'AL-vehicle-photo\'>\n<div class=\'viewed-overlay hidden\'></div>\n<div class=\'photo-overlay\'></div>\n<div class=\'overlay-menu\' data-menu>\n<div class=\'-favorite -results-gtsm item\' data-action=\'favorite\'></div>\n</div>\n<div class=\'photo\' data-background-image=\'https://images.autolist.com/image/fetch/s--j611PBXJ--/c_fill,f_auto,q_ ...
#   'pagination': '<ul><li class="previous disabled"><a>Previous</a></li><li class="selected"><a>1</a></li><li data-page="2"><a>2</a></li><li data-page="3"><a>3</a></li><li data-page="4"><a>...</a></li><li data-page="16"><a>16</a></li><li data-page="17"><a>17</a></li><li data-page="2" class="next"><a>Next</a></li></ul>'}}

# %%
type(results_json)
# Out:
# dict

# %% [markdown]
# #### Step 5 - Output Keys

# %%
results_json.keys()
# Out:
# dict_keys(['total_results_count', 'make_model_name', 'trims', 'ad_info', 'search_results', 'html'])

# %% [markdown]
# #### Step 6 - Find your Data

# %%
# model
# mileage
# year
# dealer name
# price

# %%
results_json['search_results']
# Out:
# [{'available_nationwide': False,
#   'created_at': 1642657502,
#   'recent_price_drop': None,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EB2LF647875',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EB2LF647875',
#   'clickoff_url': 'https://www.carmax.com/car/21676488?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 235652559,
#   'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21676488/1.jpg?width=1024&watermark=LYCG_1a',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--4RWLmo9_--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21676488/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#   'lat': 32.843399,
#   'lon': -96.898399,
#   'year': 2020,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$52,998',
#   'price_unformatted': 52998,
#   'mileage': '25,813 Miles',
#   'mileage_unformatted': 25813,
#   'city': 'Irving',
#   'state': 'TX',
#   'distance_from_origin': 5361,
#   'dealer_name': 'CarMax Texas Stadium (Irving) - Now Offering Curbside Pickup And Home Delivery',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '5YJ3E1EB2LF647875',
#   'provider': None,
#   'provider_name': 'carmax',
#   'always_ask_for_zip': True,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '5YJ3E1EB2LF647875',
#    'remote_dealer_id': '7115',
#    'dealer_name': 'CarMax Texas Stadium (Irving)',
#    'remote_sku': '21676488',
#    'experience': 'national_backfill',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'carmax_tx_stadium',
#    'dealer_uuid': '9cd88c7b-05af-4d4c-813e-05887e3bc6e5',
#    'dealer_group_unique_name': 'carmax',
#    'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#   'trim': 'Long Range',
#   'provider_id': 146,
#   'provider_group_id': 149,
#   'experience': 'local_if_nearby',
#   'regional': True,
#   'badges': {'position0': None, 'position1': 'fresh'},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1642311878,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJYGDEE9LF037144',
#   'vdp_url': '/tesla-model+y#vin=5YJYGDEE9LF037144',
#   'clickoff_url': 'https://www.carmax.com/car/21634963?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 235444093,
#   'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21634963/1.jpg?width=1024&watermark=LYCG_1a',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--NyWKBusk--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21634963/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#   'lat': 35.159805,
#   'lon': -80.732605,
#   'year': 2020,
#   'make': 'Tesla',
#   'model': 'Model Y',
#   'model_id': 2357,
#   'display_color': '',
#   'price': '$66,998',
#   'price_unformatted': 66998,
#   'mileage': '25,125 Miles',
#   'mileage_unformatted': 25125,
#   'city': 'Charlotte',
#   'state': 'NC',
#   'distance_from_origin': 4797,
#   'dealer_name': 'CarMax Independence Boulevard - Now Offering Curbside Pickup And Home Delivery',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '5YJYGDEE9LF037144',
#   'provider': None,
#   'provider_name': 'carmax',
#   'always_ask_for_zip': True,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '5YJYGDEE9LF037144',
#    'remote_dealer_id': '7106',
#    'dealer_name': 'CarMax Charlotte',
#    'remote_sku': '21634963',
#    'experience': 'national_backfill',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'carmax_charlotte',
#    'dealer_uuid': '96441764-9288-4d1c-9f86-10e58dcb580a',
#    'dealer_group_unique_name': 'carmax',
#    'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#   'trim': 'Long Range',
#   'provider_id': 146,
#   'provider_group_id': 149,
#   'experience': 'local_if_nearby',
#   'regional': True,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1642052749,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EC0MF936330',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EC0MF936330',
#   'clickoff_url': 'https://www.carmax.com/car/21846359?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 235203984,
#   'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21846359/1.jpg?width=1024&watermark=LYCG_1a',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--j611PBXJ--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21846359/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#   'lat': 33.27750723911677,
#   'lon': -111.735905469218,
#   'year': 2021,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$64,998',
#   'price_unformatted': 64998,
#   'mileage': '11,430 Miles',
#   'mileage_unformatted': 11430,
#   'city': 'Gilbert',
#   'state': 'AZ',
#   'distance_from_origin': 5645,
#   'dealer_name': 'CarMax Phoenix-Gilbert - Now Offering Curbside Pickup',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '5YJ3E1EC0MF936330',
#   'provider': None,
#   'provider_name': 'carmax',
#   'always_ask_for_zip': True,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '5YJ3E1EC0MF936330',
#    'remote_dealer_id': '7662',
#    'dealer_name': 'CarMax Phoenix-Gilbert',
#    'remote_sku': '21846359',
#    'experience': 'national_backfill',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'carmax_phoenix_gilbert',
#    'dealer_uuid': 'cc7db436-aae0-48a3-a245-ef29e8edc722',
#    'dealer_group_unique_name': 'carmax',
#    'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#   'trim': 'Performance',
#   'provider_id': 146,
#   'provider_group_id': 149,
#   'experience': 'local_if_nearby',
#   'regional': True,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1637726303,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EA8MF920097',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EA8MF920097',
#   'clickoff_url': 'https://www.carmax.com/car/21535430?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 232103004,
#   'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21535430/1.jpg?width=1024&watermark=LYCG_1a',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--kVn6RNFy--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21535430/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#   'lat': 43.57342334079856,
#   'lon': -116.4013098816062,
#   'year': 2021,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$51,998',
#   'price_unformatted': 51998,
#   'mileage': '9,330 Miles',
#   'mileage_unformatted': 9330,
#   'city': 'Meridian',
#   'state': 'ID',
#   'distance_from_origin': 5042,
#   'dealer_name': 'CarMax Boise (Meridian) - Now Offering Curbside Pickup',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '5YJ3E1EA8MF920097',
#   'provider': None,
#   'provider_name': 'carmax',
#   'always_ask_for_zip': True,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '5YJ3E1EA8MF920097',
#    'remote_dealer_id': '6039',
#    'dealer_name': 'CarMax Boise (Meridian)',
#    'remote_sku': '21535430',
#    'experience': 'national_backfill',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'carmax_boise_meridian',
#    'dealer_uuid': 'ceec9e6c-39bd-4db4-a1cd-b13651fe2daa',
#    'dealer_group_unique_name': 'carmax',
#    'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#   'trim': 'Standard Range Plus',
#   'provider_id': 146,
#   'provider_group_id': 149,
#   'experience': 'local_if_nearby',
#   'regional': True,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1642657504,
#   'recent_price_drop': None,
#   'is_hot': False,
#   'href_target': '/listings/5YJYGDEE2MF073677',
#   'vdp_url': '/tesla-model+y#vin=5YJYGDEE2MF073677',
#   'clickoff_url': 'https://www.carmax.com/car/21731461?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 235652967,
#   'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21731461/1.jpg?width=1024&watermark=LYCG_1a',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--Hxf9OFOT--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21731461/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#   'lat': 35.892673,
#   'lon': -78.55385,
#   'year': 2021,
#   'make': 'Tesla',
#   'model': 'Model Y',
#   'model_id': 2357,
#   'display_color': '',
#   'price': '$69,998',
#   'price_unformatted': 69998,
#   'mileage': '5,173 Miles',
#   'mileage_unformatted': 5173,
#   'city': 'Raleigh',
#   'state': 'NC',
#   'distance_from_origin': 4691,
#   'dealer_name': 'CarMax Capital Boulevard - Now Offering Curbside Pickup And Home Delivery',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '5YJYGDEE2MF073677',
#   'provider': None,
#   'provider_name': 'carmax',
#   'always_ask_for_zip': True,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '5YJYGDEE2MF073677',
#    'remote_dealer_id': '7282',
#    'dealer_name': 'CarMax Capital Boulevard',
#    'remote_sku': '21731461',
#    'experience': 'national_backfill',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'carmax_capital_boulevard',
#    'dealer_uuid': '37dab682-0d2a-4174-b8d0-187d7ede25c7',
#    'dealer_group_unique_name': 'carmax',
#    'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#   'trim': 'Long Range',
#   'provider_id': 146,
#   'provider_group_id': 149,
#   'experience': 'local_if_nearby',
#   'regional': True,
#   'badges': {'position0': None, 'position1': 'fresh'},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1642139500,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EA8MF020543',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EA8MF020543',
#   'clickoff_url': 'https://www.carmax.com/car/21714781?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 235285547,
#   'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21714781/1.jpg?width=1024&watermark=LYCG_1a',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--PoXBn-ps--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21714781/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#   'lat': 26.097263,
#   'lon': -80.245949,
#   'year': 2021,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$51,998',
#   'price_unformatted': 51998,
#   'mileage': '8,051 Miles',
#   'mileage_unformatted': 8051,
#   'city': 'Davie',
#   'state': 'FL',
#   'distance_from_origin': 5329,
#   'dealer_name': 'CarMax Ft. Lauderdale - Now Offering Curbside Pickup And Home Delivery',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '5YJ3E1EA8MF020543',
#   'provider': None,
#   'provider_name': 'carmax',
#   'always_ask_for_zip': True,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '5YJ3E1EA8MF020543',
#    'remote_dealer_id': '7108',
#    'dealer_name': 'CarMax Ft. Lauderdale',
#    'remote_sku': '21714781',
#    'experience': 'national_backfill',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'carmax_ft_lauderdale',
#    'dealer_uuid': 'e021e97a-0130-48f0-a061-638533e61fbd',
#    'dealer_group_unique_name': 'carmax',
#    'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#   'trim': 'Standard Range Plus',
#   'provider_id': 146,
#   'provider_group_id': 149,
#   'experience': 'local_if_nearby',
#   'regional': True,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1641793113,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EA2MF092029',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EA2MF092029',
#   'clickoff_url': 'https://www.carmax.com/car/21814324?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 235018238,
#   'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21814324/1.jpg?width=1024&watermark=LYCG_1a',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--L8Sw8qNm--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21814324/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#   'lat': 35.707237,
#   'lon': -81.305038,
#   'year': 2021,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$49,998',
#   'price_unformatted': 49998,
#   'mileage': '1,900 Miles',
#   'mileage_unformatted': 1900,
#   'city': 'Hickory',
#   'state': 'NC',
#   'distance_from_origin': 4780,
#   'dealer_name': 'CarMax Hickory - Now Offering Curbside Pickup And Home Delivery',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '5YJ3E1EA2MF092029',
#   'provider': None,
#   'provider_name': 'carmax',
#   'always_ask_for_zip': True,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '5YJ3E1EA2MF092029',
#    'remote_dealer_id': '7231',
#    'dealer_name': 'CarMax Hickory',
#    'remote_sku': '21814324',
#    'experience': 'national_backfill',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'carmax_hickory',
#    'dealer_uuid': '0062325e-2e3a-494f-8296-9d4acc6d6e61',
#    'dealer_group_unique_name': 'carmax',
#    'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#   'trim': 'Standard Range Plus',
#   'provider_id': 146,
#   'provider_group_id': 149,
#   'experience': 'local_if_nearby',
#   'regional': True,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1642218150,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EA0MF058932',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EA0MF058932',
#   'clickoff_url': 'https://www.carmax.com/car/21203815?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 235357867,
#   'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21203815/1.jpg?width=1024&watermark=LYCG_1a',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--0f-rVBTn--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21203815/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#   'lat': 34.08762181731687,
#   'lon': -83.94131109254148,
#   'year': 2021,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$53,998',
#   'price_unformatted': 53998,
#   'mileage': '2,097 Miles',
#   'mileage_unformatted': 2097,
#   'city': 'Buford',
#   'state': 'GA',
#   'distance_from_origin': 4951,
#   'dealer_name': 'CarMax Buford - Now Offering Curbside Pickup And Home Delivery',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '5YJ3E1EA0MF058932',
#   'provider': None,
#   'provider_name': 'carmax',
#   'always_ask_for_zip': True,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '5YJ3E1EA0MF058932',
#    'remote_dealer_id': '6031',
#    'dealer_name': 'CarMax Buford',
#    'remote_sku': '21203815',
#    'experience': 'national_backfill',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'carmax_buford',
#    'dealer_uuid': 'c889115b-42e1-4bb7-a6b2-a24c23e47c5a',
#    'dealer_group_unique_name': 'carmax',
#    'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#   'trim': 'Standard Range Plus',
#   'provider_id': 146,
#   'provider_group_id': 149,
#   'experience': 'local_if_nearby',
#   'regional': True,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1642574077,
#   'recent_price_drop': True,
#   'is_hot': False,
#   'href_target': '/listings/5YJYGDED1MF103193',
#   'vdp_url': '/tesla-model+y#vin=5YJYGDED1MF103193',
#   'clickoff_url': 'https://www.carmax.com/car/21841351?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 235574176,
#   'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21841351/1.jpg?width=1024&watermark=LYCG_1a',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--jdspCU1s--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21841351/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#   'lat': 39.723848,
#   'lon': -105.185903,
#   'year': 2021,
#   'make': 'Tesla',
#   'model': 'Model Y',
#   'model_id': 2357,
#   'display_color': '',
#   'price': '$62,998',
#   'price_unformatted': 62998,
#   'mileage': '11,355 Miles',
#   'mileage_unformatted': 11355,
#   'city': 'Golden',
#   'state': 'CO',
#   'distance_from_origin': 5103,
#   'dealer_name': 'CarMax Golden - Now Offering Curbside Pickup And Home Delivery',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '5YJYGDED1MF103193',
#   'provider': None,
#   'provider_name': 'carmax',
#   'always_ask_for_zip': True,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '5YJYGDED1MF103193',
#    'remote_dealer_id': '6047',
#    'dealer_name': 'CarMax Golden',
#    'remote_sku': '21841351',
#    'experience': 'national_backfill',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'carmax_golden',
#    'dealer_uuid': 'a1ce32c8-c56c-47a6-88bc-317076285732',
#    'dealer_group_unique_name': 'carmax',
#    'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#   'trim': 'Standard Range',
#   'provider_id': 146,
#   'provider_group_id': 149,
#   'experience': 'local_if_nearby',
#   'regional': True,
#   'badges': {'position0': None, 'position1': 'price_drop'},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1642225503,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EB5JF113346',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EB5JF113346',
#   'clickoff_url': 'https://www.carmax.com/car/21763670?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 235368927,
#   'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21763670/1.jpg?width=1024&watermark=LYCG_1a',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--8j496LmM--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21763670/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#   'lat': 39.009819,
#   'lon': -77.436104,
#   'year': 2018,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$55,998',
#   'price_unformatted': 55998,
#   'mileage': '19,346 Miles',
#   'mileage_unformatted': 19346,
#   'city': 'Sterling',
#   'state': 'VA',
#   'distance_from_origin': 4475,
#   'dealer_name': 'CarMax Dulles - Now Offering Curbside Pickup And Home Delivery',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '5YJ3E1EB5JF113346',
#   'provider': None,
#   'provider_name': 'carmax',
#   'always_ask_for_zip': True,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '5YJ3E1EB5JF113346',
#    'remote_dealer_id': '7132',
#    'dealer_name': 'CarMax Dulles',
#    'remote_sku': '21763670',
#    'experience': 'national_backfill',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'carmax_dulles',
#    'dealer_uuid': '23575ced-c04b-435e-bf7a-cc2eb9716958',
#    'dealer_group_unique_name': 'carmax',
#    'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#   'trim': 'Performance',
#   'provider_id': 146,
#   'provider_group_id': 149,
#   'experience': 'local_if_nearby',
#   'regional': True,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1642657475,
#   'recent_price_drop': None,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EB0LF801788',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EB0LF801788',
#   'clickoff_url': 'https://www.carmax.com/car/21327936?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 235649953,
#   'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21327936/1.jpg?width=1024&watermark=LYCG_1a',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--5H8UYZym--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21327936/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#   'lat': 39.536456,
#   'lon': -104.777566,
#   'year': 2020,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$54,998',
#   'price_unformatted': 54998,
#   'mileage': '21,657 Miles',
#   'mileage_unformatted': 21657,
#   'city': 'Parker',
#   'state': 'CO',
#   'distance_from_origin': 5107,
#   'dealer_name': 'CarMax Parker - Now Offering Curbside Pickup And Home Delivery',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '5YJ3E1EB0LF801788',
#   'provider': None,
#   'provider_name': 'carmax',
#   'always_ask_for_zip': True,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '5YJ3E1EB0LF801788',
#    'remote_dealer_id': '6010',
#    'dealer_name': 'CarMax Parker',
#    'remote_sku': '21327936',
#    'experience': 'national_backfill',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'carmax_parker',
#    'dealer_uuid': '0bf2bb92-5a5c-4ea9-9b3c-9c9c2f50d9d4',
#    'dealer_group_unique_name': 'carmax',
#    'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#   'trim': 'Long Range',
#   'provider_id': 146,
#   'provider_group_id': 149,
#   'experience': 'local_if_nearby',
#   'regional': True,
#   'badges': {'position0': None, 'position1': 'fresh'},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1641620291,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJSA1E4XJF269701',
#   'vdp_url': '/tesla-model+s#vin=5YJSA1E4XJF269701',
#   'clickoff_url': 'https://www.carmax.com/car/21477558?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 234906584,
#   'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21477558/1.jpg?width=1024&watermark=LYCG_1a',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--Jv3utlgu--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21477558/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#   'lat': 34.08762181731687,
#   'lon': -83.94131109254148,
#   'year': 2018,
#   'make': 'Tesla',
#   'model': 'Model S',
#   'model_id': 2006,
#   'display_color': '',
#   'price': '$83,998',
#   'price_unformatted': 83998,
#   'mileage': '31,061 Miles',
#   'mileage_unformatted': 31061,
#   'city': 'Buford',
#   'state': 'GA',
#   'distance_from_origin': 4951,
#   'dealer_name': 'CarMax Buford - Now Offering Curbside Pickup And Home Delivery',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '5YJSA1E4XJF269701',
#   'provider': None,
#   'provider_name': 'carmax',
#   'always_ask_for_zip': True,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '5YJSA1E4XJF269701',
#    'remote_dealer_id': '6031',
#    'dealer_name': 'CarMax Buford',
#    'remote_sku': '21477558',
#    'experience': 'national_backfill',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'carmax_buford',
#    'dealer_uuid': 'c889115b-42e1-4bb7-a6b2-a24c23e47c5a',
#    'dealer_group_unique_name': 'carmax',
#    'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#   'trim': 'P100D',
#   'provider_id': 146,
#   'provider_group_id': 149,
#   'experience': 'local_if_nearby',
#   'regional': True,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1635917648,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EC6LF669239',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EC6LF669239',
#   'clickoff_url': 'https://www.carmax.com/car/21428251?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 230729809,
#   'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21428251/1.jpg?width=1024&watermark=LYCG_1a',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--e0R3Ei1w--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21428251/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#   'lat': 41.63382176507668,
#   'lon': -93.73456214956924,
#   'year': 2020,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$63,998',
#   'price_unformatted': 63998,
#   'mileage': '12,236 Miles',
#   'mileage_unformatted': 12236,
#   'city': 'Urbandale',
#   'state': 'IA',
#   'distance_from_origin': 4738,
#   'dealer_name': 'CarMax Des Moines - Now Offering Curbside Pickup',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '5YJ3E1EC6LF669239',
#   'provider': None,
#   'provider_name': 'carmax',
#   'always_ask_for_zip': True,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '5YJ3E1EC6LF669239',
#    'remote_dealer_id': '6004',
#    'dealer_name': 'CarMax Des Moines',
#    'remote_sku': '21428251',
#    'experience': 'national_backfill',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'carmax_des_moines',
#    'dealer_uuid': '9544c995-51e7-4b0a-9680-255fd5e26caf',
#    'dealer_group_unique_name': 'carmax',
#    'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#   'trim': 'Performance',
#   'provider_id': 146,
#   'provider_group_id': 149,
#   'experience': 'local_if_nearby',
#   'regional': True,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1637127831,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EB9JF119392',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EB9JF119392',
#   'clickoff_url': 'https://www.carmax.com/car/21529925?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 231641143,
#   'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21529925/1.jpg?width=1024&watermark=LYCG_1a',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--ecJ2zE5j--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21529925/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#   'lat': 34.22445047136432,
#   'lon': -118.6334774051356,
#   'year': 2018,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$50,998',
#   'price_unformatted': 50998,
#   'mileage': '20,895 Miles',
#   'mileage_unformatted': 20895,
#   'city': 'Canoga Park',
#   'state': 'CA',
#   'distance_from_origin': 5696,
#   'dealer_name': 'CarMax Canoga Park - Now Offering Curbside Pickup And Home Delivery',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '5YJ3E1EB9JF119392',
#   'provider': None,
#   'provider_name': 'carmax',
#   'always_ask_for_zip': True,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '5YJ3E1EB9JF119392',
#    'remote_dealer_id': '7124',
#    'dealer_name': 'CarMax Canoga Park',
#    'remote_sku': '21529925',
#    'experience': 'national_backfill',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'carmax_canoga_park',
#    'dealer_uuid': '60fcb806-1728-4076-8ad1-4db049729175',
#    'dealer_group_unique_name': 'carmax',
#    'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#   'trim': 'Long Range',
#   'provider_id': 146,
#   'provider_group_id': 149,
#   'experience': 'local_if_nearby',
#   'regional': True,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1641620293,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EA7MF064534',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EA7MF064534',
#   'clickoff_url': 'https://www.carmax.com/car/21671558?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 234906767,
#   'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21671558/1.jpg?width=1024&watermark=LYCG_1a',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--IViPIN_J--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21671558/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#   'lat': 47.81055093002225,
#   'lon': -122.2807501062141,
#   'year': 2021,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$49,998',
#   'price_unformatted': 49998,
#   'mileage': '2,400 Miles',
#   'mileage_unformatted': 2400,
#   'city': 'Lynnwood',
#   'state': 'WA',
#   'distance_from_origin': 4836,
#   'dealer_name': 'CarMax Lynnwood - Now Offering Curbside Pickup',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '5YJ3E1EA7MF064534',
#   'provider': None,
#   'provider_name': 'carmax',
#   'always_ask_for_zip': True,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '5YJ3E1EA7MF064534',
#    'remote_dealer_id': '7250',
#    'dealer_name': 'CarMax Lynnwood',
#    'remote_sku': '21671558',
#    'experience': 'national_backfill',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'carmax_lynnwood',
#    'dealer_uuid': '04cb1617-8ff4-4348-80b1-7c6e0dd411b8',
#    'dealer_group_unique_name': 'carmax',
#    'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#   'trim': 'Standard Range Plus',
#   'provider_id': 146,
#   'provider_group_id': 149,
#   'experience': 'local_if_nearby',
#   'regional': True,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1641620293,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EB7LF638721',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EB7LF638721',
#   'clickoff_url': 'https://www.carmax.com/car/21685810?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 234906777,
#   'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21685810/1.jpg?width=1024&watermark=LYCG_1a',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--6vAhPm8a--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21685810/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#   'lat': 37.691496,
#   'lon': -121.847734,
#   'year': 2020,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$56,998',
#   'price_unformatted': 56998,
#   'mileage': '6,978 Miles',
#   'mileage_unformatted': 6978,
#   'city': 'Pleasanton',
#   'state': 'CA',
#   'distance_from_origin': 5509,
#   'dealer_name': 'CarMax Pleasanton - Now Open',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '5YJ3E1EB7LF638721',
#   'provider': None,
#   'provider_name': 'carmax',
#   'always_ask_for_zip': True,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '5YJ3E1EB7LF638721',
#    'remote_dealer_id': '6068',
#    'dealer_name': 'CarMax Pleasanton',
#    'remote_sku': '21685810',
#    'experience': 'national_backfill',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'carmax_pleasanton',
#    'dealer_uuid': 'aa30dd9c-1b75-4a66-a7d3-078716560d2a',
#    'dealer_group_unique_name': 'carmax',
#    'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#   'trim': 'Long Range',
#   'provider_id': 146,
#   'provider_group_id': 149,
#   'experience': 'local_if_nearby',
#   'regional': True,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1641965673,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EA7LF793275',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EA7LF793275',
#   'clickoff_url': 'https://www.carmax.com/car/21580598?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 235117629,
#   'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21580598/1.jpg?width=1024&watermark=LYCG_1a',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--ZLrRzPEu--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21580598/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#   'lat': 38.68322332188854,
#   'lon': -77.3151275475306,
#   'year': 2020,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$49,998',
#   'price_unformatted': 49998,
#   'mileage': '9,006 Miles',
#   'mileage_unformatted': 9006,
#   'city': 'Woodbridge',
#   'state': 'VA',
#   'distance_from_origin': 4491,
#   'dealer_name': 'CarMax Potomac Mills - Now Offering Curbside Pickup And Home Delivery',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '5YJ3E1EA7LF793275',
#   'provider': None,
#   'provider_name': 'carmax',
#   'always_ask_for_zip': True,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '5YJ3E1EA7LF793275',
#    'remote_dealer_id': '7183',
#    'dealer_name': 'CarMax Potomac Mills',
#    'remote_sku': '21580598',
#    'experience': 'national_backfill',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'carmax_potomac_mills',
#    'dealer_uuid': '6ebede17-d435-4c4f-b7f8-f6eedfb40ff6',
#    'dealer_group_unique_name': 'carmax',
#    'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#   'trim': 'Standard Range Plus',
#   'provider_id': 146,
#   'provider_group_id': 149,
#   'experience': 'local_if_nearby',
#   'regional': True,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1642052737,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EA2JF109150',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EA2JF109150',
#   'clickoff_url': 'https://www.carmax.com/car/21799330?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 235199330,
#   'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21799330/1.jpg?width=1024&watermark=LYCG_1a',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--9u137Oim--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21799330/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#   'lat': 41.54908,
#   'lon': -87.783585,
#   'year': 2018,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$47,998',
#   'price_unformatted': 47998,
#   'mileage': '18,533 Miles',
#   'mileage_unformatted': 18533,
#   'city': 'Tinley Park',
#   'state': 'IL',
#   'distance_from_origin': 4600,
#   'dealer_name': 'CarMax Tinley Park - Now Offering Curbside Pickup',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '5YJ3E1EA2JF109150',
#   'provider': None,
#   'provider_name': 'carmax',
#   'always_ask_for_zip': True,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '5YJ3E1EA2JF109150',
#    'remote_dealer_id': '7123',
#    'dealer_name': 'CarMax Tinley Park',
#    'remote_sku': '21799330',
#    'experience': 'national_backfill',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'carmax_tinley_park',
#    'dealer_uuid': '97ab92b0-3a56-48f4-8961-b8a65074eed7',
#    'dealer_group_unique_name': 'carmax',
#    'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#   'trim': 'Long Range',
#   'provider_id': 146,
#   'provider_group_id': 149,
#   'experience': 'local_if_nearby',
#   'regional': True,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1640065422,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EC7LF736382',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EC7LF736382',
#   'clickoff_url': 'https://www.carmax.com/car/21199485?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 233835751,
#   'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21199485/1.jpg?width=1024&watermark=LYCG_1a',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--bruDAj03--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21199485/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#   'lat': 39.39208799035347,
#   'lon': -76.40076215697658,
#   'year': 2020,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$57,998',
#   'price_unformatted': 57998,
#   'mileage': '27,736 Miles',
#   'mileage_unformatted': 27736,
#   'city': 'White Marsh',
#   'state': 'MD',
#   'distance_from_origin': 4424,
#   'dealer_name': 'CarMax White Marsh - Now Offering Curbside Pickup',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '5YJ3E1EC7LF736382',
#   'provider': None,
#   'provider_name': 'carmax',
#   'always_ask_for_zip': True,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '5YJ3E1EC7LF736382',
#    'remote_dealer_id': '7121',
#    'dealer_name': 'CarMax White Marsh',
#    'remote_sku': '21199485',
#    'experience': 'national_backfill',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'carmax_white_marsh',
#    'dealer_uuid': '55714391-254e-4c7b-b1b8-497bbdb16a9d',
#    'dealer_group_unique_name': 'carmax',
#    'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#   'trim': 'Performance',
#   'provider_id': 146,
#   'provider_group_id': 149,
#   'experience': 'local_if_nearby',
#   'regional': True,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1641620291,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EA6MF069580',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EA6MF069580',
#   'clickoff_url': 'https://www.carmax.com/car/21900916?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 234906564,
#   'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21900916/1.jpg?width=1024&watermark=LYCG_1a',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--QOLLKqpM--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21900916/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#   'lat': 34.23518276789216,
#   'lon': -119.180077971384,
#   'year': 2021,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$50,998',
#   'price_unformatted': 50998,
#   'mileage': '7,872 Miles',
#   'mileage_unformatted': 7872,
#   'city': 'Oxnard',
#   'state': 'CA',
#   'distance_from_origin': 5703,
#   'dealer_name': 'CarMax Oxnard - Now Offering Curbside Pickup And Home Delivery',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '5YJ3E1EA6MF069580',
#   'provider': None,
#   'provider_name': 'carmax',
#   'always_ask_for_zip': True,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '5YJ3E1EA6MF069580',
#    'remote_dealer_id': '6014',
#    'dealer_name': 'CarMax Oxnard',
#    'remote_sku': '21900916',
#    'experience': 'national_backfill',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'carmax_oxnard',
#    'dealer_uuid': 'dfee9eab-fb2c-4d95-b57b-61908c33aa04',
#    'dealer_group_unique_name': 'carmax',
#    'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#   'trim': 'Standard Range Plus',
#   'provider_id': 146,
#   'provider_group_id': 149,
#   'experience': 'local_if_nearby',
#   'regional': True,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False}]

# %%
len(results_json['search_results'])
# Out:
# 20

# %%
result_items = results_json['search_results']

# %%
# starting point for first result
results_json['search_results'][0]
# Out:
# {'available_nationwide': False,
#  'created_at': 1642657502,
#  'recent_price_drop': None,
#  'is_hot': False,
#  'href_target': '/listings/5YJ3E1EB2LF647875',
#  'vdp_url': '/tesla-model+3#vin=5YJ3E1EB2LF647875',
#  'clickoff_url': 'https://www.carmax.com/car/21676488?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#  'accepts_leads': True,
#  'open_in_new_window': False,
#  'id': 235652559,
#  'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21676488/1.jpg?width=1024&watermark=LYCG_1a',
#  'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--4RWLmo9_--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21676488/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#  'lat': 32.843399,
#  'lon': -96.898399,
#  'year': 2020,
#  'make': 'Tesla',
#  'model': 'Model 3',
#  'model_id': 2217,
#  'display_color': '',
#  'price': '$52,998',
#  'price_unformatted': 52998,
#  'mileage': '25,813 Miles',
#  'mileage_unformatted': 25813,
#  'city': 'Irving',
#  'state': 'TX',
#  'distance_from_origin': 5361,
#  'dealer_name': 'CarMax Texas Stadium (Irving) - Now Offering Curbside Pickup And Home Delivery',
#  'show_message_box': None,
#  'email_opt_default': True,
#  'show_financing_checkbox': None,
#  'show_new_mileage': False,
#  'show_thankyou_page': False,
#  'show_rsrp': True,
#  'click_off': False,
#  'pre_check_thankyou': True,
#  'cpl_value': 15,
#  'partner_type': 'dealer_direct',
#  'vin': '5YJ3E1EB2LF647875',
#  'provider': None,
#  'provider_name': 'carmax',
#  'always_ask_for_zip': True,
#  'listing_id': None,
#  'time_on_market': None,
#  'total_price_change': None,
#  'relative_price_difference': None,
#  'listimate_category': None,
#  'listimate_text': None,
#  'photo_urls': [],
#  'tracking_params': {'id_from_provider': '5YJ3E1EB2LF647875',
#   'remote_dealer_id': '7115',
#   'dealer_name': 'CarMax Texas Stadium (Irving)',
#   'remote_sku': '21676488',
#   'experience': 'national_backfill',
#   'rooftop_unique_name': None,
#   'rooftop_uuid': None,
#   'dealer_unique_name': 'carmax_tx_stadium',
#   'dealer_uuid': '9cd88c7b-05af-4d4c-813e-05887e3bc6e5',
#   'dealer_group_unique_name': 'carmax',
#   'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#  'trim': 'Long Range',
#  'provider_id': 146,
#  'provider_group_id': 149,
#  'experience': 'local_if_nearby',
#  'regional': True,
#  'badges': {'position0': None, 'position1': 'fresh'},
#  'quick_picks_eligible': False}

# %%
# model
results_json['search_results'][0]['model']
# Out:
# 'Model 3'

# %%
# mileage
results_json['search_results'][0]['mileage']
# Out:
# '25,813 Miles'

# %%
# year
results_json['search_results'][0]['year']
# Out:
# 2020

# %%
# dealer name
results_json['search_results'][0]['dealer_name']
# Out:
# 'CarMax Texas Stadium (Irving) - Now Offering Curbside Pickup And Home Delivery'

# %%
# price
results_json['search_results'][0]['price']
# Out:
# '$52,998'

# %% [markdown]
# #### Step 7 - Put everything together - Loop through results and append data inside a list

# %%
model = []
mileage = []
year = []
dealer_name = []
price = []

for result in result_items:
    # model
    model.append(result['model'])
    
    # mileage
    mileage.append(result['mileage'])
    
    # year
    year.append(result['year'])
    
    # dealer_name
    dealer_name.append(result['dealer_name'])
    
    # price
    price.append(result['price'])

# %% [markdown]
# #### Step 8 - Pandas Dataframe - Single Page

# %%
tesla_df = pd.DataFrame({'Model': model, 'Mileage': mileage, 'Year': year,
                      'Dealer Name': dealer_name, 'Price': price})

# %%
tesla_df
# Out:
#       Model       Mileage  Year  \
# 0   Model 3  25,813 Miles  2020
# 1   Model Y  25,125 Miles  2020
# 2   Model 3  11,430 Miles  2021
# 3   Model 3   9,330 Miles  2021
# 4   Model Y   5,173 Miles  2021
# 5   Model 3   8,051 Miles  2021
# 6   Model 3   1,900 Miles  2021
# 7   Model 3   2,097 Miles  2021
# 8   Model Y  11,355 Miles  2021
# 9   Model 3  19,346 Miles  2018
# 10  Model 3  21,657 Miles  2020
# 11  Model S  31,061 Miles  2018
# 12  Model 3  12,236 Miles  2020
# 13  Model 3  20,895 Miles  2018
# 14  Model 3   2,400 Miles  2021
# 15  Model 3   6,978 Miles  2020
# 16  Model 3   9,006 Miles  2020
# 17  Model 3  18,533 Miles  2018
# 18  Model 3  27,736 Miles  2020
# 19  Model 3   7,872 Miles  2021
#
#                                           Dealer Name    Price
# 0   CarMax Texas Stadium (Irving) - Now Offering C...  $52,998
# 1   CarMax Independence Boulevard - Now Offering C...  $66,998
# 2   CarMax Phoenix-Gilbert - Now Offering Curbside...  $64,998
# 3   CarMax Boise (Meridian) - Now Offering Curbsid...  $51,998
# 4   CarMax Capital Boulevard - Now Offering Curbsi...  $69,998
# 5   CarMax Ft. Lauderdale - Now Offering Curbside ...  $51,998
# 6   CarMax Hickory - Now Offering Curbside Pickup ...  $49,998
# 7   CarMax Buford - Now Offering Curbside Pickup A...  $53,998
# 8   CarMax Golden - Now Offering Curbside Pickup A...  $62,998
# 9   CarMax Dulles - Now Offering Curbside Pickup A...  $55,998
# 10  CarMax Parker - Now Offering Curbside Pickup A...  $54,998
# 11  CarMax Buford - Now Offering Curbside Pickup A...  $83,998
# 12   CarMax Des Moines - Now Offering Curbside Pickup  $63,998
# 13  CarMax Canoga Park - Now Offering Curbside Pic...  $50,998
# 14     CarMax Lynnwood - Now Offering Curbside Pickup  $49,998
# 15                       CarMax Pleasanton - Now Open  $56,998
# 16  CarMax Potomac Mills - Now Offering Curbside P...  $49,998
# 17  CarMax Tinley Park - Now Offering Curbside Pickup  $47,998
# 18  CarMax White Marsh - Now Offering Curbside Pickup  $57,998
# 19  CarMax Oxnard - Now Offering Curbside Pickup A...  $50,998

# %%
tesla_df.to_excel('tesla_single_page.xlsx', index=False)

# %% [markdown]
# #### Step 9 - Scraping Multiple Pages (here: 5pages to get 100 results)

# %%
headers = {
    'authority': 'www.autolist.com',
    'sec-ch-ua': '^\\^Chromium^\\^;v=^\\^94^\\^, ^\\^Google',
    'accept': '*/*',
    'x-requested-with': 'XMLHttpRequest',
    'sec-ch-ua-mobile': '?0',
    'x-autolist-session-guid': 'c9fb9ffb-2c06-4468-a3d0-c26290c6994f',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4590.0 Safari/537.36',
    'sec-ch-ua-platform': '^\\^Windows^\\^',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-mode': 'cors',
    'sec-fetch-dest': 'empty',
    'referer': 'https://www.autolist.com/listings',
    'accept-language': 'en-US,en;q=0.9',
    'cookie': 'ec=eyJlZGdlVXNlckFnZW50IjoiTW96aWxsYS81LjAgKFdpbmRvd3MgTlQgMTAuMDsgV2luNjQ7IHg2NCkgQXBwbGVXZWJLaXQvNTM3LjM2IChLSFRNTCwgbGlrZSBHZWNrbykgQ2hyb21lLzk0LjAuNDU5MC4wIFNhZmFyaS81MzcuMzYifQ==; client_guid_timestamp=1602952f-d1bf-4936-82e3-cbdedfa11d2d.1627825394925; scavenger-a493=...; _sp_ses.8ca5=*; _gid=GA1.2.96049973.1627825395; _fbp=fb.1.1627825395573.409117512; __gads=ID=c459f8bf6d0987dd:T=1627825394:S=ALNI_MaW1epD3HNJsvJQTCnPWSJCcOdE_w; AMP_TOKEN=^%^24NOT_FOUND; sp-nuid=e4461948-a1a2-45a1-88f8-45c2889d9576; _gcl_au=1.1.519751617.1627825557; _ga_152345333=GS1.1.1627825395.1.1.1627828426.0; _ga=GA1.2.2118379867.1627825395; cto_bundle=WV1etl8zMUc1cGt6WnZNSEZMYWhwNnJjUXpTYzQxVzZ6QzM5VE1tWXZFcjQ3ZWhrNTlETG1CemlUdmNFYUtIbXdCQTNFelJmY3h6QXA0SlVIZml0WVg2OWQxZlBPMmRqbExXNU9XZTM0V0VaR09tbHBvJTJGdERCb21zZUVKJTJCTG1vVzlDV0w2VjA0bDklMkJnRjdrMmZPUExmJTJGY0l6USUzRCUzRA; _gat=1; _sp_id.8ca5=d3d3f60d-371c-4289-92fe-1c6f66b4979f.1627825395.1.1627828912.1627825395.8bc1e545-8ca1-448e-b1ba-ec8d2c359ada',
    'if-none-match': 'W/^\\^c6f72fa4ef059e03ea0309ebd57c197d^\\^',
}

model = []
mileage = []
year = []
dealer_name = []
price = []

for i in range(1, 6):
    
    params = (
        ('make', 'Tesla'),
        ('zip', '198099'),
        ('location', 'Sankt-Peterburg'),
        ('latitude', '59.897206'),
        ('longitude', '30.2604628'),
        ('radius', '50'),
        ('page', str(i)),
    )

    # response variable for the get request
    response = requests.get('https://www.autolist.com/api/cwv/seo/listings', headers=headers, params=params)
    
    # json object
    results_json = response.json()
    
    # result items (20 times for each page)
    result_items = results_json['search_results']
    
    for result in result_items:
        # model
        model.append(result['model'])
        
        # mileage
        mileage.append(result['mileage'])
        
        # year
        year.append(result['year'])
        
        # dealer_name
        dealer_name.append(result['dealer_name'])
        
        # price
        price.append(result['price'])

# %%
tesla_multiple_df = pd.DataFrame({'Model': model, 'Mileage': mileage, 'Year': year,
                                  'Dealer Name': dealer_name, 'Price': price})

# %%
tesla_multiple_df
# Out:
#       Model       Mileage  Year  \
# 0   Model 3  25,813 Miles  2020
# 1   Model Y  25,125 Miles  2020
# 2   Model 3  11,430 Miles  2021
# 3   Model 3   9,330 Miles  2021
# 4   Model Y   5,173 Miles  2021
# ..      ...           ...   ...
# 95  Model 3  14,316 Miles  2020
# 96  Model 3  35,446 Miles  2018
# 97  Model 3  28,608 Miles  2020
# 98  Model 3  31,393 Miles  2020
# 99  Model 3  12,408 Miles  2021
#
#                                           Dealer Name    Price
# 0   CarMax Texas Stadium (Irving) - Now Offering C...  $52,998
# 1   CarMax Independence Boulevard - Now Offering C...  $66,998
# 2   CarMax Phoenix-Gilbert - Now Offering Curbside...  $64,998
# 3   CarMax Boise (Meridian) - Now Offering Curbsid...  $51,998
# 4   CarMax Capital Boulevard - Now Offering Curbsi...  $69,998
# ..                                                ...      ...
# 95  CarMax Dulles - Now Offering Curbside Pickup A...  $52,998
# 96   CarMax Naperville - Now Offering Curbside Pickup  $43,998
# 97                       CarMax Pleasanton - Now Open  $52,998
# 98  CarMax King Of Prussia - Now Offering Curbside...  $45,998
# 99  CarMax Orlando - Now Offering Curbside Pickup ...  $57,998
#
# [100 rows x 5 columns]

# %% [markdown]
# #### Step 10 - Store Results in Excel

# %%
tesla_multiple_df.to_excel('tesla_multiple_pages.xlsx', index=False)
